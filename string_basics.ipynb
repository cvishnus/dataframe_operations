# %% [markdown]
# 1. Longest Substring Without Repeating Characters
# Problem: Given a string, find the length of the longest substring without repeating characters.
#
# Example:
# "abcabcbb" → Output: 3 (substring: "abc")

# %%
def longest_sub(input):
    max_len =1
    max_str=''
    for i in range(len(input)):
        sub_str= input[i]
        for j in range(i+1, len(input)):
            if input[j] in sub_str:
                break
            else:
                sub_str = sub_str+input[j]
                print(sub_str)
        if len(sub_str)>max_len:
            max_len=len(sub_str)
            max_str = sub_str
    return max_str

# %%
longest_sub('abcdddabcbb')
# Out:
# ab
# abc
# abcd
# bc
# bcd
# cd
# da
# dab
# dabc
# ab
# abc
# bc
# cb
# 'abcd'

# %% [markdown]
# 2. Group Anagrams
# Problem: Given a list of strings, group them into anagrams.
#
# Example:
# ["eat", "tea", "tan", "ate", "nat", "bat"]
# → Output: [["eat", "tea", "ate"], ["tan", "nat"], ["bat"]]

# %%
def find_ana(input_ls):
    ref_ana=input_ls[0]
    for i in range(1,len(input_ls)):
        if len(ref_ana)==len(input_ls[i]):
           1 if j in ref_ana for j in input_ls[i] else 0
